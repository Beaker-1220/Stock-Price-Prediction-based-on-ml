# %% [markdown]
# ### Imports

# %%
# !pip install gymnasium
# !pip install gym_anytrading
# !pip install stable_baselines3
# !pip install stable-baselines3[extra]
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple/
# Requirement already satisfied: gymnasium in /Users/frz/anaconda3/lib/python3.10/site-packages (0.29.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/frz/anaconda3/lib/python3.10/site-packages (from gymnasium) (4.4.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/frz/anaconda3/lib/python3.10/site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: numpy>=1.21.0 in /Users/frz/anaconda3/lib/python3.10/site-packages (from gymnasium) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/frz/anaconda3/lib/python3.10/site-packages (from gymnasium) (2.0.0)
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple/
# Requirement already satisfied: gym_anytrading in /Users/frz/anaconda3/lib/python3.10/site-packages (2.0.0)
# Requirement already satisfied: pandas>=0.24.2 in /Users/frz/anaconda3/lib/python3.10/site-packages (from gym_anytrading) (1.5.3)
# Requirement already satisfied: gymnasium>=0.29.1 in /Users/frz/anaconda3/lib/python3.10/site-packages (from gym_anytrading) (0.29.1)
# Requirement already satisfied: numpy>=1.16.4 in /Users/frz/anaconda3/lib/python3.10/site-packages (from gym_anytrading) (1.23.5)
# Requirement already satisfied: matplotlib>=3.1.1 in /Users/frz/anaconda3/lib/python3.10/site-packages (from gym_anytrading) (3.7.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/frz/anaconda3/lib/python3.10/site-packages (from gymnasium>=0.29.1->gym_anytrading) (0.0.4)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/frz/anaconda3/lib/python3.10/site-packages (from gymnasium>=0.29.1->gym_anytrading) (4.4.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/frz/anaconda3/lib/python3.10/site-packages (from gymnasium>=0.29.1->gym_anytrading) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/frz/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.1.1->gym_anytrading) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/frz/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.1.1->gym_anytrading) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/frz/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.1.1->gym_anytrading) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/frz/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.1.1->gym_anytrading) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /Users/frz/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.1.1->gym_anytrading) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/frz/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.1.1->gym_anytrading) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/frz/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.1.1->gym_anytrading) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/frz/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.1.1->gym_anytrading) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/frz/anaconda3/lib/python3.10/site-packages (from pandas>=0.24.2->gym_anytrading) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/frz/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->gym_anytrading) (1.16.0)
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple/
# Requirement already satisfied: stable_baselines3 in /Users/frz/anaconda3/lib/python3.10/site-packages (2.2.1)
# Requirement already satisfied: matplotlib in /Users/frz/anaconda3/lib/python3.10/site-packages (from stable_baselines3) (3.7.1)
# Requirement already satisfied: cloudpickle in /Users/frz/anaconda3/lib/python3.10/site-packages (from stable_baselines3) (2.0.0)
# Requirement already satisfied: numpy>=1.20 in /Users/frz/anaconda3/lib/python3.10/site-packages (from stable_baselines3) (1.23.5)
# Requirement already satisfied: torch>=1.13 in /Users/frz/anaconda3/lib/python3.10/site-packages (from stable_baselines3) (2.1.1)
# Requirement already satisfied: pandas in /Users/frz/anaconda3/lib/python3.10/site-packages (from stable_baselines3) (1.5.3)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /Users/frz/anaconda3/lib/python3.10/site-packages (from stable_baselines3) (0.29.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/frz/anaconda3/lib/python3.10/site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (4.4.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/frz/anaconda3/lib/python3.10/site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: jinja2 in /Users/frz/anaconda3/lib/python3.10/site-packages (from torch>=1.13->stable_baselines3) (3.1.2)
# Requirement already satisfied: sympy in /Users/frz/anaconda3/lib/python3.10/site-packages (from torch>=1.13->stable_baselines3) (1.11.1)
# Requirement already satisfied: networkx in /Users/frz/anaconda3/lib/python3.10/site-packages (from torch>=1.13->stable_baselines3) (2.8.4)
# Requirement already satisfied: filelock in /Users/frz/anaconda3/lib/python3.10/site-packages (from torch>=1.13->stable_baselines3) (3.12.4)
# Requirement already satisfied: fsspec in /Users/frz/anaconda3/lib/python3.10/site-packages (from torch>=1.13->stable_baselines3) (2022.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/frz/anaconda3/lib/python3.10/site-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/frz/anaconda3/lib/python3.10/site-packages (from matplotlib->stable_baselines3) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /Users/frz/anaconda3/lib/python3.10/site-packages (from matplotlib->stable_baselines3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/frz/anaconda3/lib/python3.10/site-packages (from matplotlib->stable_baselines3) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/frz/anaconda3/lib/python3.10/site-packages (from matplotlib->stable_baselines3) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/frz/anaconda3/lib/python3.10/site-packages (from matplotlib->stable_baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/frz/anaconda3/lib/python3.10/site-packages (from matplotlib->stable_baselines3) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/frz/anaconda3/lib/python3.10/site-packages (from matplotlib->stable_baselines3) (1.0.5)
# Requirement already satisfied: pytz>=2020.1 in /Users/frz/anaconda3/lib/python3.10/site-packages (from pandas->stable_baselines3) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/frz/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/frz/anaconda3/lib/python3.10/site-packages (from jinja2->torch>=1.13->stable_baselines3) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/frz/anaconda3/lib/python3.10/site-packages/mpmath-1.2.1-py3.10.egg (from sympy->torch>=1.13->stable_baselines3) (1.2.1)
# zsh:1: no matches found: stable-baselines3[extra]

# %%
from tqdm import tqdm
import random

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import gymnasium as gym
import gym_anytrading

from stable_baselines3 import A2C, PPO
from stable_baselines3.common.callbacks import BaseCallback

import torch

# %% [markdown]
# ### Create Env

# %%
# 读取数据
df = pd.read_csv('data/HSI_日线数据_处理后.csv', encoding='utf-8')

env_name = 'stocks-v0'  
env = gym.make('stocks-v0', df=df, frame_bound=(30, len(df)), window_size=5)

df.head()
# Out:
#       Open     High      Low    Close  Volume  Turnover
# 0  8591.45  8608.12  8398.43  8591.45     0.0       0.0
# 1  8828.91  8828.91  8606.51  8828.91     0.0       0.0
# 2  8808.28  8944.31  8790.79  8808.28     0.0       0.0
# 3  9117.02  9140.84  8863.83  9117.02     0.0       0.0
# 4  9193.83  9228.50  9131.54  9193.83     0.0       0.0

# %% [markdown]
# ### Define Functions

# %%
def print_stats(reward_over_episodes):
    """  Print Reward  """

    avg = np.mean(reward_over_episodes)
    min = np.min(reward_over_episodes)
    max = np.max(reward_over_episodes)

    print (f'Min. Reward          : {min:>10.3f}')
    print (f'Avg. Reward          : {avg:>10.3f}')
    print (f'Max. Reward          : {max:>10.3f}')

    return min, avg, max


# ProgressBarCallback for model.learn()
class ProgressBarCallback(BaseCallback):

    def __init__(self, check_freq: int, verbose: int = 1):
        super().__init__(verbose)
        self.check_freq = check_freq

    def _on_training_start(self) -> None:
        """
        This method is called before the first rollout starts.
        """
        self.progress_bar = tqdm(total=self.model._total_timesteps, desc="model.learn()")

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:
            self.progress_bar.update(self.check_freq)
        return True
    
    def _on_training_end(self) -> None:
        """
        This event is triggered before exiting the `learn()` method.
        """
        self.progress_bar.close()


# TRAINING + TEST
def train_test_model(model, env, seed, total_num_episodes, total_learning_timesteps=10_000):
    """ if model=None then execute 'Random actions' """

    # reproduce training and test
    print('-' * 80)
    obs = env.reset(seed=seed)
    torch.manual_seed(seed)
    random.seed(seed)
    np.random.seed(seed)

    vec_env = None

    if model is not None:
        print(f'model {type(model)}')
        print(f'policy {type(model.policy)}')
        # print(f'model.learn(): {total_learning_timesteps} timesteps ...')

        # custom callback for 'progress_bar'
        model.learn(total_timesteps=total_learning_timesteps, callback=ProgressBarCallback(100))
        # model.learn(total_timesteps=total_learning_timesteps, progress_bar=True)
        # ImportError: You must install tqdm and rich in order to use the progress bar callback. 
        # It is included if you install stable-baselines with the extra packages: `pip install stable-baselines3[extra]`

        vec_env = model.get_env()
        obs = vec_env.reset()
    else:
        print ("RANDOM actions")

    reward_over_episodes = []

    tbar = tqdm(range(total_num_episodes))

    for episode in tbar:
        
        if vec_env: 
            obs = vec_env.reset()
        else:
            obs, info = env.reset()

        total_reward = 0
        done = False

        while not done:
            if model is not None:
                action, _states = model.predict(obs)
                obs, reward, done, info = vec_env.step(action)
            else: # random
                action = env.action_space.sample()
                obs, reward, terminated, truncated, info = env.step(action)
                done = terminated or truncated

            total_reward += reward
            if done:
                break

        reward_over_episodes.append(total_reward)

        if episode % 10 == 0:
            avg_reward = np.mean(reward_over_episodes)
            tbar.set_description(f'Episode: {episode}, Avg. Reward: {avg_reward:.3f}')
            tbar.update()

    tbar.close()
    avg_reward = np.mean(reward_over_episodes)

    return reward_over_episodes

# %% [markdown]
# ### Train + Test Env

# %%
seed = 42  # random seed
total_num_episodes = 50

print ("env_name                 :", env_name)
print ("seed                     :", seed)

# INIT matplotlib
plot_settings = {}
plot_data = {'x': [i for i in range(1, total_num_episodes + 1)]}

# Random actions
model = None 
total_learning_timesteps = 0
rewards = train_test_model(model, env, seed, total_num_episodes, total_learning_timesteps)
min, avg, max = print_stats(rewards)
class_name = f'Random actions'
label = f'Avg. {avg:>7.2f} : {class_name}'
plot_data['rnd_rewards'] = rewards
plot_settings['rnd_rewards'] = {'label': label}

learning_timesteps_list_in_K = [25]
# learning_timesteps_list_in_K = [50, 250, 500]
# learning_timesteps_list_in_K = [500, 1000, 3000, 5000]

# RL Algorithms: https://stable-baselines3.readthedocs.io/en/master/guide/algos.html
model_class_list = [A2C, PPO]

for timesteps in learning_timesteps_list_in_K:
    total_learning_timesteps = timesteps * 1000
    step_key = f'{timesteps}K'

    for model_class in model_class_list:
        policy_dict = model_class.policy_aliases
        # https://stable-baselines3.readthedocs.io/en/master/guide/custom_policy.html
        # MlpPolicy or MlpLstmPolicy
        policy = policy_dict.get('MlpPolicy')
        if policy is None:
            policy = policy_dict.get('MlpLstmPolicy')
        # print ('policy:', policy, 'model_class:', model_class)

        try:
            model = model_class(policy, env, verbose=0)
            class_name = type(model).__qualname__
            plot_key = f'{class_name}_rewards_'+step_key
            rewards = train_test_model(model, env, seed, total_num_episodes, total_learning_timesteps)
            min, avg, max, = print_stats(rewards)
            label = f'Avg. {avg:>7.2f} : {class_name} - {step_key}'
            plot_data[plot_key] = rewards
            plot_settings[plot_key] = {'label': label}     
                   
        except Exception as e:
            print(f"ERROR: {str(e)}")
            continue
# Out:
# env_name                 : stocks-v0
# seed                     : 42
# --------------------------------------------------------------------------------
# RANDOM actions
# Episode: 40, Avg. Reward: -25305.860: 100%|██████████| 50/50 [00:02<00:00, 20.80it/s]
# Min. Reward          : -25305.860
# Avg. Reward          : -25305.860
# Max. Reward          : -25305.860
# --------------------------------------------------------------------------------
# model <class 'stable_baselines3.a2c.a2c.A2C'>
# policy <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# model.learn(): 100%|██████████| 25000/25000 [00:12<00:00, 1983.90it/s]
# Episode: 40, Avg. Reward: 7616.537: 100%|██████████| 50/50 [01:01<00:00,  1.24s/it]
# Min. Reward          : -22352.217
# Avg. Reward          :   7451.113
# Max. Reward          :  36395.180
# --------------------------------------------------------------------------------
# model <class 'stable_baselines3.ppo.ppo.PPO'>
# policy <class 'stable_baselines3.common.policies.ActorCriticPolicy'>
# model.learn(): 26600it [00:13, 1956.18it/s]
# Episode: 40, Avg. Reward: 8493.391: 100%|██████████| 50/50 [01:00<00:00,  1.22s/it]
# Min. Reward          : -11118.866
# Avg. Reward          :   8034.470
# Max. Reward          :  26527.795

# %% [markdown]
# ### Plot Results

# %%
# Redrawing the plot with 300 DPI and assigning specific colors to each line

sns.set_style('whitegrid')
plt.figure(figsize=(8, 6), dpi=300)

colors = ['blue', 'green', 'pink']  # Defining different colors for each line
keys = list(plot_data.keys())[1:]  # Excluding 'x' from the keys

for key, color in zip(keys, colors):
    label = plot_settings[key]['label'] if key in plot_settings else key
    plt.plot(plot_data['x'], plot_data[key], linewidth=1, label=label, color=color)

plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Random vs. SB3 Agents')
plt.legend()
plt.show()
